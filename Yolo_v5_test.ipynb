# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom

# Images
img = 'https://ultralytics.com/images/zidane.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Willy/.cache\torch\hub\master.zip
# YOLOv5  2022-7-11 Python-3.8.10 torch-1.11.0+cu113 CUDA:0 (NVIDIA GeForce 930MX, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1210.1ms pre-process, 3186.9ms inference, 22.9ms NMS per image at shape (1, 3, 384, 640)

# %%
results.save("result.jpg")
# Out:
# Saved 1 image to runs\detect\exp

# %%
from PIL import Image
display_img = Image.open('result.jpg')
display(display_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x799>
