# %%
import numpy as np
import tensorflow as tf
import imageai

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13682320272054232889,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 1436408219
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13800207717590532315
#  physical_device_desc: "device: 0, name: NVIDIA GeForce 930MX, pci bus id: 0000:01:00.0, compute capability: 5.0"]

# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(execution_path , "yolov3.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "military.jpg"), output_image_path=os.path.join(execution_path , "result.jpg"), minimum_percentage_probability=30)

for eachObject in detections:
    print(eachObject["name"] , " : ", eachObject["percentage_probability"], " : ", eachObject["box_points"] )
    print("--------------------------------")
# Out:
# truck  :  99.48633909225464  :  [87, 217, 782, 497]
# --------------------------------
# truck  :  97.74035215377808  :  [550, 229, 1185, 611]
# --------------------------------
# truck  :  91.82497262954712  :  [4, 192, 181, 461]
# --------------------------------

# %%
from IPython.display import Image
Image("result.jpg")

# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(execution_path , "yolo.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "military2.jpg"), output_image_path=os.path.join(execution_path , "result.jpg"), minimum_percentage_probability=30)

for eachObject in detections:
    print(eachObject["name"] , " : ", eachObject["percentage_probability"], " : ", eachObject["box_points"] )
    print("--------------------------------")
# Out:
# truck  :  98.89672994613647  :  [3, 102, 467, 419]
# --------------------------------
# truck  :  84.41402912139893  :  [420, 206, 837, 405]
# --------------------------------
# person  :  99.36211109161377  :  [480, 232, 549, 400]
# --------------------------------
# person  :  95.5742597579956  :  [813, 262, 858, 373]
# --------------------------------
# person  :  31.924161314964294  :  [846, 258, 863, 343]
# --------------------------------

# %%
from IPython.display import Image
Image("result.jpg")

# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(execution_path , "yolo.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "airplanes.jpg"), output_image_path=os.path.join(execution_path , "result.jpg"), minimum_percentage_probability=30)

for eachObject in detections:
    print(eachObject["name"] , " : ", eachObject["percentage_probability"], " : ", eachObject["box_points"] )
    print("--------------------------------")
# Out:
# airplane  :  99.6849000453949  :  [535, 198, 1078, 393]
# --------------------------------
# airplane  :  84.82561111450195  :  [296, 360, 880, 566]
# --------------------------------
# airplane  :  93.37753653526306  :  [187, 501, 674, 697]
# --------------------------------

# %%
from IPython.display import Image
Image("result.jpg")
